# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np
import pandas as pd

# %%
cd = pd.read_csv("IRIS.csv")

# %%
cd
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
plt.scatter(cd["sepal_width"],cd["sepal_length"], marker='o',color='green')
plt.scatter(cd["petal_width"],cd["petal_length"], marker='*',color='black')

# %%
def f(x, y):
    return  np. cos(X*Y*100)  * np.cos(x)
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 90)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)
fig = plt.figure()
ax = plt.axes(projection ='3d')

ax.contour3D(X, Y, Z)

# %%
def f(x, y):
    return  np. cos(X*Y*100)  * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 90)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='gray');

# %%
plt.contourf(X, Y, Z, 30,cmap='gray');
plt.colorbar();

# %%
plt.contourf(X, Y, Z, 30, cmap='gray')
plt.colorbar();

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='gray')
plt.colorbar()
#plt.axis(n='image');

# %%
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='gray', alpha=0.5)
plt.colorbar();

# %%
cd1 = pd.DataFrame({'name': ['mary', 'Joseph'],
                    'drink': ['wine', 'Beer']})
cd2 = pd.DataFrame({'name': ['pater', 'poul','mary' ],
                    'food': ['fish', 'beans', 'bread']})
print(cd1)
print(cd2)
# Out:
#      name drink
# 0    mary  wine
# 1  Joseph  Beer
#     name   food
# 0  pater   fish
# 1   poul  beans
# 2   mary  bread

# %%
cd3 = pd.merge(cd1, cd2)
cd3
# Out:
#    name drink   food
# 0  mary  wine  bread

# %%
pd.merge(cd1,cd2,on='name',how='outer')
# Out:
#      name drink   food
# 0    mary  wine  bread
# 1  Joseph  Beer    NaN
# 2   pater   NaN   fish
# 3    poul   NaN  beans
